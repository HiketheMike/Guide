# %% [markdown]
# # <span style = 'color:orange'> Anaconda Navigator
# <img src="../Pictures/Anaconda logo.jpg" style='width:500px; height:250px; margin:10px auto'>

# %% [markdown]
# ## <span style = 'color:red'> Step-by-step process

# %% [markdown]
# <div style = 'border:2px solid black; padding:10px'>
#
# ## **Step 1: Download Anaconda Navigator**
# - Go to [Anaconda Navigator](https://www.anaconda.com/products/navigator)
# - Press **Download Now**
# - You can choose to **Register** your email or **skip** it. If you choose to register, then there should be a download link sent to your **Email Address**.

# %% [markdown]
# <div style= 'border:2px solid black; padding:10px'>
#
# ## **Step 2: Choose a suitable version for your Device**
#
# - The installation should recognize your system, and you can use the **Default installation** (e.g, my operating system is Windows):
#
# <img src="../Pictures/Default_Installation.png" style ='width:350; height:275; display:block; margin:10px auto'>
#
# - There are also a few other versions that you can choose to download.
# <img src='../Pictures/Optional_Installation.png' style='width:350; height:275; display:block; margin:10px auto'>
#
#
# </div>
# <div class = 'alert alert-info' style = 'border:2px solid black'>
#
# ### 🪟 *Windows Guide*
# - For Windows, it is simple; we only need to click on either the **Default installation** or the **64-Bit Graphical Installer (912.3M)** to download.
#
#
#
# ### 🍎*MacOS Guide*
# - When you click on the **Default installation**, you will be asked to download either **Intel** or **Apple Silicon**. The installation of this depends on whether your Mac is running on an INTEL or M1/M2/M3 chip. Here are the steps for you to check:
#    - Click on the **Apple icon** on the top left of your screen and go to **About This Mac** and look for **Chip**:
#    - If you see:
#      - `Apple M1`, `M2`, or `M3` --> **Download Apple Silicon** OR **64-Bit (Apple silicon) Graphical Installer (704.7M)**
#      - `Intel Core i5`, `i7`, etc. --> **Download Intel** OR **64-Bit (Intel chip) Graphical Installer (734.7M)**
#
# - Don't DOWNLOAD **64-Bit (Apple silicon) Command Line Installer (707.3M)** OR **64-Bit (Intel chip) Command Line Installer (731.2M)** as they require you to use the command prompt to download them properly.
#
#
# ### 🐧 *Linux Guide*
#
# </div>

# %% [markdown]
# <div style='border:2px solid black; padding:10px'>
#
# ## <strong> Step 3: Finishing Installation</strong>
# - For both Mac and Windows, the **default options** are sufficient and should not be changed, just click continue and proceed with the installation (in case you are unsure about what to choose or that you clicked something wrong, you can check for these options in the videos below and follow them)
# - Open up **Anaconda Navigator**.
# </div>

# %% [markdown]
# <div class = 'alert alert-success'>
# ✅ <strong>Anaconda Navigator</strong> is now Ready to be used. You now have access to all the essential tools for *Data Analysis** and **Machine Learning**. Here's how your Navigator should look when opened up: <break></break>
#
# <img src= '../Pictures/Anaconda_navigator.png' style ='margin:20px auto; display:block; height:500px; width:1000px'>
#
# </div>

# %% [markdown]
# ## <span style = 'color:red'> Video Guide (from the Official Anaconda website)

# %%
# FOR WINDOWS
from IPython.display import Video, Image, YouTubeVideo
YouTubeVideo("yFeVEAeOcnE", width=1000, height=500)

# %%
# FOR MACOS
from IPython.display import Video, Image, YouTubeVideo
YouTubeVideo('DNu8pQOYRGg', width = 1000, height = 500)

# %%
# For LINUX
from IPython.display import Video, Image, YouTubeVideo
YouTubeVideo('sU2mXjOB-fA', width = 1000, height = 500)

# %% [markdown]
# # <span style = 'color:orange'> Github Desktop
# <img src='../Pictures/Github_desktop.png' style = 'width:500px; height: 250px; margin:10px auto; display:block '/>

# %% [markdown]
# ## <span style = 'color:red'> Step-by-step process

# %% [markdown]
# <div style='border: 2px solid black; padding:10px'>
#
# ## **Step 1: Download GitHub Desktop**
# - Go to [Github Desktop](https://desktop.github.com/download/)
#   <img src='../Pictures/Github_download.png' style='width:850px; display:block; height:400px; margin:10px auto'>
#
# </div>
# <div class = 'alert alert-info' style = 'border:2px solid black' >
#
# ### 🪟🍎 *Windows Guide and MacOS Guide**
# - For Windows, it is simple; we only need to click on either the **Default installation** or the **64-Bit Graphical Installer (912.3M)** to download.
# - Downloading GitHub is more Straightforward, for your corresponding system, click on either **Download for Windows (64-bit)** or **download for macOS**.
# - Once it is downloaded, run the installer.
#
# ### 🐧 *Linux Guide*
# Sadly it doesn't officially support **Linux** devices (Linux users will be taught to use Git directly instead).
#
# > => Once it is downloaded, run the installer.
# </div>

# %% [markdown]
# <div style = 'border:2px solid black; padding:10px'>
#
# ## **Step 2: Install GitHub Desktop**
# - After downloading, click on the file and wait for it to **Install**
# - After opening GitHub, it would ask you to link with your **GitHub account** as well as **Configure Git**, **skip this step** for now as it doesn't affect the process.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <strong>✅ GitHub is Ready!</strong>
# <p style="margin-bottom: 5px;">You can now <strong>Clone</strong> and <strong>Pull</strong> online repositories to your local computer.</p>
# <img src='../Pictures/Github_menu.png' style='width:850px; display:block; height:400px; margin:10px auto'>
# <p style="margin: 10px 0 5px 0;"><strong>Next Steps:</strong></p>
# <ol style="margin-top: 5px; padding-left: 20px;">
#   <li>Your GitHub Desktop interface should look like the configured setup</li>
#   <li>Click on the <strong>Clone a repository from the Internet...</strong> to proceed</li>
# </ol>
# </div>

# %% [markdown]
# ## <span style = 'color:red'> Cloning a Github Repository

# %% [markdown]
# <div class="alert alert-warning">
# <strong>⚠️ Before Proceeding:</strong>
# <br><br>
# We need to define:
# <ul>
#   <li>The <strong>Repository URL</strong> to clone</li>
#   <li>The <strong style="color:red">Directory</strong> to clone into (<span style="color:red">EXTREMELY IMPORTANT</span>)</li>
# </ul>
# Using the <strong>wrong path</strong> will cause Jupyter Notebook/Lab to <strong>fail to recognize</strong> the cloned files!
# <br><br>
# <img src='../Pictures/Cloning_5.png' style='width:350px; height:275px; display:block; margin:10px auto;'/>
# </div>

# %% [markdown]
# <div style="border: 2px solid black; padding: 10px;">
#
# ## **Step 1: Obtain the URL**
# - First, go to [GitHub website](https://github.com/) and search for the name **Hikethemike** and look into the **Users** section and click on the name.
#
#
# <img src='../Pictures/Cloning_1.png' alt ="Drawing" style='width:750px; height:275px; display:block; margin:10px auto'>
#
# - Now go to the **Repositories** section and look for **Codes** repository, click on it.
#
# <img src='../Pictures/Cloning_2.png' alt="Drawing" style='width:750px; height:275px; display:block; margin:10px auto'>
#
# - After that you are taken to my online repo, Without going into much detail, these are all the files that i made and stored it on a **remote repository**, what we're now going to do, is to **clone** it directly into your computer so that everyone use my code (or any other individual's code and notebooks).
#
# - Next, head onto the **<> Codes** button, wherein you are given the **URL** in **HTTPS** to copy and then put onto **GitHub Desktop**.
#
# <img src='../Pictures/Cloning_3.png' alt="drawing" style='width:350px; height:275px; display:block; margin:10px auto'>
#
# - Here's the link shown on the picture: https://github.com/HiketheMike/Codes.git
# </div>

# %% [markdown]
# <div style="border: 2px solid black; padding: 10px;">
#
# ## **Step 2: Define the Local Path**
# - On YOUR **Jupyter Notebook/lab** write this function:
# ```python
# import os
# os.getcwd()
#
# # Example Output (Your own output should look like this)
# 'C:\\Users\\LENOVO\\'
# ```
#
# - It will Output the **Directory** that Jupyter is connecting to, **copy that Directory Path** and put it in the GitHub Desktop.
# - You might also get a **warning** saying that the files are not empty, simply add a name after the **Directory** to fix the issue (for example: `C:\Users\LENOVO\Codes`)
#
# </div>

# %% [markdown]
# <div style="border: 2px solid black; padding: 10px;">
#
# ## **Step 3: Putting it all together**
# - After Identifying the **URL** and the **Directory**, simply copy it to the Box in GitHub Desktop like this:
#
# <img src='../Pictures/Cloning_6.png' style='width:350px; height:275px; display:block; margin: 10px auto'>
#
# - It will Clone the GitHub Repository named **Codes** to your Laptop now.

# %% [markdown]
# <div class="alert alert-success">
# Now you should be able to open the <strong>Codes</strong> file in your Jupyter Notebook/Lab.
# <br><br>
# <strong>Note:</strong> The repository shown here is my personal one (<code>Hikethemike</code>). Dr. Omer Cayirli has his own repository named <strong><code>DROCLB</code></strong>. To access it:
# <ol>
#   <li>Redo all the previous steps, keeping in mind the directory.</li>
#   <li>When searching on <strong>GitHub.com</strong>, use <code>DROCLB</code> instead of <code>Hikethemike</code>.</li>
#   <li>Clone his repository to access its contents.</li>
# </ol>
# </div>

# %% [markdown]
# # <span style = 'color:orange'> Visual Studio Code
#
# <img src="../Pictures/VSC_logo.png" style = "height:300px; width:500px; margin:10px auto; display: block">
#
# - As an Optional Application for your Work, you can choose to use **Jupyter Lab** in Anaconda Navigator, that should suffice.
# - VSC might be easier for you to start and learn how to code, so it wouldn't hurt to show you how to use **VSC through Anaconda Navigator**.

# %% [markdown]
# ## <span style = 'color:red'> Step-by-step Process

# %% [markdown]
# <div style = 'border:2px solid black; padding:10px'>
#
#
# ## **Step 1: Download Visual Studio Code**
# - Go to [Visual Studio Code](https://code.visualstudio.com/download) and choose the version for your system.
#
# <img src="../Pictures/VSC_download.png" style="border:2px; margin:10px auto; width: 850px; height:450px; display:block">
#
# <div class = 'alert alert-info''>
#
# ### 🪟🍎🐧 **Windows Guide and MacOS Guide, Linux Guide**
# -  For **Windows** and **MacOS**, click on the **Primary Download Button**, and the system should automatically detect which system you are operating.
# - **Linux** users need to check what type of Distribution they are using. For the most common type of Linux users, you will be using **Ubuntu**, but that may vary. Check with your device systems and find the suitable version to download.
#
# > => Once it is downloaded, run the installer.
# </div>

# %% [markdown]
# <div style = 'border:2px solid black; padding:10px'>
#
# ## **Step 2: Installation**
# - For both Mac and Windows, the **default options** are sufficient and should not be changed, just click continue and proceed with the installation
# - Open up **Anaconda Navigator** and **Visual Studio Code** should appear as one of the installed apps across all Environments.
# <img src = '../Pictures/Anaconda_VSC.png'  style='width:850px; display:block; height:400px; margin:10px auto'>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <strong>✅ Visual Studio Code is Ready!</strong>
#
# <p style="margin-bottom: 5px;">You can now use <strong>Visual Studio Code</strong> through Anaconda Navigator</p>
# <img src='../Pictures/VSC_startup.png' style='width:850px; display:block; height:400px; margin:10px auto'>
# <p style="margin: 10px 0 5px 0;"><strong>Next Steps:</strong></p>
# <ol style="margin-top: 5px; padding-left: 20px;">
#   <li>Your Visual Studio Code interface should look like the configured setup</li>
#   <li>Select preference if you like, if not just click on the <strong>Mark done</strong> at the bottom to proceed.</li>
# </ol>
# </div>

# %% [markdown]
# <div style = 'border:2px solid black; padding:10px'>
#
# ## **Step 3: Downloading Extensions**
# - As we are in VSC, we need to download the **Jupyter Notebook** and **python** extension, this is required for VSC to recognize and work with Jupyter Notebook (.ipynb) files.
# - On the top, go to **Search [Administrator]** and type `>Extensions: Install Extensions`, and there should be Extensions appear on the Left of your screen.
# - In that tab, type **Jupyter extension** and install it if you have not installed it
#
# <img src = '../Pictures/Jupyter_extension.png' style='width:850px; display:block; height:400px; margin:10px auto'>
#
# - Do the same for the **Python extension**
#
# <img src = '../Pictures/Python_extension.png' style='width:850px; display:block; height:400px; margin:10px auto'>
# </div>
